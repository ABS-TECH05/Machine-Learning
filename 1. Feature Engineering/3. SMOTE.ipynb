# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)¶
# ### SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=1000,n_redundant=0, n_features=2, n_clusters_per_class=1,
                    weights=[0.90], random_state=12)

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
# !pip install imblearn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

## transform dataset using smote
oversample = SMOTE()
X, y = oversample.fit_resample(final_df[['f1', 'f2']], final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
oversampled_df = pd.concat([df1, df2], axis=1)

# %%
plt.scatter(oversampled_df['f1'], oversampled_df['f2'], c=oversampled_df['target'])

# %% [markdown]
# ## 1. Breast Cancer Dataset

# %%
## My practise
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df["target"] = data.target

df.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                  0.11890       0
# 1        20.57         17.77  ...                  0.08902       0
# 2        19.69         21.25  ...                  0.08758       0
# 3        11.42         20.38  ...                  0.17300       0
# 4        20.29         14.34  ...                  0.07678       0
#
# [5 rows x 31 columns]

# %%
df
# Out:
#      mean radius  mean texture  ...  worst fractal dimension  target
# 0          17.99         10.38  ...                  0.11890       0
# 1          20.57         17.77  ...                  0.08902       0
# 2          19.69         21.25  ...                  0.08758       0
# 3          11.42         20.38  ...                  0.17300       0
# 4          20.29         14.34  ...                  0.07678       0
# ..           ...           ...  ...                      ...     ...
# 564        21.56         22.39  ...                  0.07115       0
# 565        20.13         28.25  ...                  0.06637       0
# 566        16.60         28.08  ...                  0.07820       0
# 567        20.60         29.33  ...                  0.12400       0
# 568         7.76         24.54  ...                  0.07039       1
#
# [569 rows x 31 columns]

# %%
X,y=make_classification(n_samples=1000, n_features=2, n_redundant=0,
                        n_clusters_per_class=1, weights=[0.95], random_state=42)
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0  1.073546 -1.101339       0
# 1  0.755945 -1.172352       0
# 2  1.354479 -0.948528       0
# 3  3.103090  0.233485       0
# 4  1.951888 -0.270157       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    945
# 1     55
# Name: count, dtype: int64

# %%
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
sample = SMOTE()
X,y = sample.fit_resample(final_df[['f1','f2']], final_df['target'])

# %%
X.shape
# Out:
# (1890, 2)

# %%
y.shape
# Out:
# (1890,)

# %%
len(y[y==0])
# Out:
# 945

# %%
len(y[y==1])
# Out:
# 945

# %%
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
sampled_df = pd.concat([df1, df2], axis=1)

# %%
plt.scatter(sampled_df['f1'], sampled_df['f2'], c=sampled_df['target'])

# %% [markdown]
# ## 2. Wine Dataset

# %%
from sklearn.datasets import load_wine

data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 0    14.23        1.71  2.43  ...                          3.92   1065.0       0
# 1    13.20        1.78  2.14  ...                          3.40   1050.0       0
# 2    13.16        2.36  2.67  ...                          3.17   1185.0       0
# 3    14.37        1.95  2.50  ...                          3.45   1480.0       0
# 4    13.24        2.59  2.87  ...                          2.93    735.0       0
#
# [5 rows x 14 columns]

# %%
X,y = make_classification(n_samples=1000,n_redundant=0, n_features=2, n_clusters_per_class=1,
                    weights=[0.90], random_state=12)
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
sampling = SMOTE()
X,y = sampling.fit_resample(final_df[['f1', 'f2']], final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
sampled_df = pd.concat([df1, df2], axis=1)

# %%
plt.scatter(sampled_df['f1'], sampled_df['f2'], c=sampled_df['target'])

# %% [markdown]
# ## 3. Breast Cancer Dataset (Without Imbalancing the dataset)

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df["target"] = data.target

df.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                  0.11890       0
# 1        20.57         17.77  ...                  0.08902       0
# 2        19.69         21.25  ...                  0.08758       0
# 3        11.42         20.38  ...                  0.17300       0
# 4        20.29         14.34  ...                  0.07678       0
#
# [5 rows x 31 columns]

# %%
df
# Out:
#      mean radius  mean texture  ...  worst fractal dimension  target
# 0          17.99         10.38  ...                  0.11890       0
# 1          20.57         17.77  ...                  0.08902       0
# 2          19.69         21.25  ...                  0.08758       0
# 3          11.42         20.38  ...                  0.17300       0
# 4          20.29         14.34  ...                  0.07678       0
# ..           ...           ...  ...                      ...     ...
# 564        21.56         22.39  ...                  0.07115       0
# 565        20.13         28.25  ...                  0.06637       0
# 566        16.60         28.08  ...                  0.07820       0
# 567        20.60         29.33  ...                  0.12400       0
# 568         7.76         24.54  ...                  0.07039       1
#
# [569 rows x 31 columns]

# %%
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
over_sample = SMOTE()
X,y = over_sample.fit_resample(final_df[['f1', 'f2']], final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=['target'])
concat_df = pd.concat([df1, df2], axis=1)

# %%
plt.scatter(concat_df['f1'], concat_df['f2'], c=concat_df['target'])
