# %% [markdown]
# ### Target Guided Ordinal Encoding
# It is a technique used to encode categorical variables based on their relationship with the target variable. This encoding technique is useful when we have a categorical variable with a large number of unique categories, and we want to use this variable as a feature in our machine learning model.
#
# In Target Guided Ordinal Encoding, we replace each category in the categorical variable with a numerical value based on the mean or median of the target variable for that category. This creates a monotonic relationship between the categorical variable and the target variable, which can improve the predictive power of our model.

# %%
import pandas as pd

# create a sample dataframe with a categorical variable and a target variable
df = pd.DataFrame({
    'city': ['New York', 'London', 'Paris', 'Tokyo', 'New York', 'Paris'],
    'price': [200, 150, 300, 250, 180, 320]
})

# %%
df
# Out:
#        city  price
# 0  New York    200
# 1    London    150
# 2     Paris    300
# 3     Tokyo    250
# 4  New York    180
# 5     Paris    320

# %%
mean_price = df.groupby('city')['price'].mean().to_dict()

# %%
mean_price
# Out:
# {'London': 150.0, 'New York': 190.0, 'Paris': 310.0, 'Tokyo': 250.0}

# %%
df['city_encoded'] = df['city'].map(mean_price)

# %%
df[['city', 'city_encoded']]
# Out:
#        city  city_encoded
# 0  New York         190.0
# 1    London         150.0
# 2     Paris         310.0
# 3     Tokyo         250.0
# 4  New York         190.0
# 5     Paris         310.0

# %% [markdown]
# ### Target Guided Ordinal Encoding with Iris Dataset : Time and Total Bill

# %%
import seaborn as sns
df = pd.DataFrame(sns.load_dataset('tips'))

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
mean_bill = df.groupby('time')['total_bill'].mean().to_dict()
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_14128\3722957593.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_bill = df.groupby('time')['total_bill'].mean().to_dict()

# %%
mean_bill
# Out:
# {'Lunch': 17.168676470588235, 'Dinner': 20.79715909090909}

# %%
df['time_encoded'] = df['time'].map(mean_bill)

# %%
df[['time', 'time_encoded']]
# Out:
#        time time_encoded
# 0    Dinner    20.797159
# 1    Dinner    20.797159
# 2    Dinner    20.797159
# 3    Dinner    20.797159
# 4    Dinner    20.797159
# ..      ...          ...
# 239  Dinner    20.797159
# 240  Dinner    20.797159
# 241  Dinner    20.797159
# 242  Dinner    20.797159
# 243  Dinner    20.797159
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Target Guided Ordinal Encoding with Iris Dataset : Day and Total Bill

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size time_encoded
# 0         16.99  1.01  Female     No   Sun  Dinner     2    20.797159
# 1         10.34  1.66    Male     No   Sun  Dinner     3    20.797159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    20.797159
# 3         23.68  3.31    Male     No   Sun  Dinner     2    20.797159
# 4         24.59  3.61  Female     No   Sun  Dinner     4    20.797159
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.797159
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    20.797159
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    20.797159
# 242       17.82  1.75    Male     No   Sat  Dinner     2    20.797159
# 243       18.78  3.00  Female     No  Thur  Dinner     2    20.797159
#
# [244 rows x 8 columns]

# %%
mean_bill = df.groupby('day')['total_bill'].mean().to_dict()
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_14128\615754428.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_bill = df.groupby('day')['total_bill'].mean().to_dict()

# %%
mean_bill
# Out:
# {'Thur': 17.682741935483868,
#  'Fri': 17.15157894736842,
#  'Sat': 20.44137931034483,
#  'Sun': 21.41}

# %%
df['day_encoded'] = df['day'].map(mean_bill)

# %%
df[['day', 'day_encoded']]
# Out:
#       day day_encoded
# 0     Sun   21.410000
# 1     Sun   21.410000
# 2     Sun   21.410000
# 3     Sun   21.410000
# 4     Sun   21.410000
# ..    ...         ...
# 239   Sat   20.441379
# 240   Sat   20.441379
# 241   Sat   20.441379
# 242   Sat   20.441379
# 243  Thur   17.682742
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Target Guided Ordinal Encoding with Iris Dataset : Size and Total Bill

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size time_encoded  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    20.797159
# 1         10.34  1.66    Male     No   Sun  Dinner     3    20.797159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    20.797159
# 3         23.68  3.31    Male     No   Sun  Dinner     2    20.797159
# 4         24.59  3.61  Female     No   Sun  Dinner     4    20.797159
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.797159
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    20.797159
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    20.797159
# 242       17.82  1.75    Male     No   Sat  Dinner     2    20.797159
# 243       18.78  3.00  Female     No  Thur  Dinner     2    20.797159
#
#     day_encoded
# 0     21.410000
# 1     21.410000
# 2     21.410000
# 3     21.410000
# 4     21.410000
# ..          ...
# ...

# %%
mean_bill = df.groupby('size')['total_bill'].mean().to_dict()

# %%
mean_bill
# Out:
# {1: 7.2425,
#  2: 16.44801282051282,
#  3: 23.277631578947368,
#  4: 28.613513513513514,
#  5: 30.068,
#  6: 34.83}

# %%
df['size_encoded'] = df['size'].map(mean_bill)

# %%
df[['size', 'size_encoded']]
# Out:
#      size  size_encoded
# 0       2     16.448013
# 1       3     23.277632
# 2       3     23.277632
# 3       2     16.448013
# 4       4     28.613514
# ..    ...           ...
# 239     3     23.277632
# 240     2     16.448013
# 241     2     16.448013
# 242     2     16.448013
# 243     2     16.448013
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Target Guided Ordinal Encoding with Iris Dataset : Smoker and Total Bill

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size time_encoded  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    20.797159
# 1         10.34  1.66    Male     No   Sun  Dinner     3    20.797159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    20.797159
# 3         23.68  3.31    Male     No   Sun  Dinner     2    20.797159
# 4         24.59  3.61  Female     No   Sun  Dinner     4    20.797159
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.797159
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    20.797159
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    20.797159
# 242       17.82  1.75    Male     No   Sat  Dinner     2    20.797159
# 243       18.78  3.00  Female     No  Thur  Dinner     2    20.797159
#
#     day_encoded  size_encoded
# 0     21.410000     16.448013
# 1     21.410000     23.277632
# 2     21.410000     23.277632
# ...

# %%
mean_bill = df.groupby('smoker')['total_bill'].mean().to_dict()
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_14128\312441715.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_bill = df.groupby('smoker')['total_bill'].mean().to_dict()

# %%
mean_bill
# Out:
# {'Yes': 20.756344086021503, 'No': 19.188278145695364}

# %%
df['smoker_encoded'] = df['smoker'].map(mean_bill)

# %%
df[['smoker', 'smoker_encoded']]
# Out:
#     smoker smoker_encoded
# 0       No      19.188278
# 1       No      19.188278
# 2       No      19.188278
# 3       No      19.188278
# 4       No      19.188278
# ..     ...            ...
# 239     No      19.188278
# 240    Yes      20.756344
# 241    Yes      20.756344
# 242     No      19.188278
# 243     No      19.188278
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Target Guided Ordinal Encoding with Iris Dataset : Sex and Total Bill

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size time_encoded  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    20.797159
# 1         10.34  1.66    Male     No   Sun  Dinner     3    20.797159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    20.797159
# 3         23.68  3.31    Male     No   Sun  Dinner     2    20.797159
# 4         24.59  3.61  Female     No   Sun  Dinner     4    20.797159
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.797159
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    20.797159
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    20.797159
# 242       17.82  1.75    Male     No   Sat  Dinner     2    20.797159
# 243       18.78  3.00  Female     No  Thur  Dinner     2    20.797159
#
#     day_encoded  size_encoded smoker_encoded
# 0     21.410000     16.448013      19.188278
# ...

# %%
mean_bill = df.groupby('sex')['total_bill'].mean().to_dict()
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_14128\2242973093.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_bill = df.groupby('sex')['total_bill'].mean().to_dict()

# %%
mean_bill
# Out:
# {'Male': 20.74407643312102, 'Female': 18.05689655172414}

# %%
df['sex_encoded'] = df['sex'].map(mean_bill)

# %%
df[['sex', 'sex_encoded']]
# Out:
#         sex sex_encoded
# 0    Female   18.056897
# 1      Male   20.744076
# 2      Male   20.744076
# 3      Male   20.744076
# 4    Female   18.056897
# ..      ...         ...
# 239    Male   20.744076
# 240  Female   18.056897
# 241    Male   20.744076
# 242    Male   20.744076
# 243  Female   18.056897
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Target Guided Ordinal Encoding with Iris Dataset

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size time_encoded  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    20.797159
# 1         10.34  1.66    Male     No   Sun  Dinner     3    20.797159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    20.797159
# 3         23.68  3.31    Male     No   Sun  Dinner     2    20.797159
# 4         24.59  3.61  Female     No   Sun  Dinner     4    20.797159
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.797159
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    20.797159
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    20.797159
# 242       17.82  1.75    Male     No   Sat  Dinner     2    20.797159
# 243       18.78  3.00  Female     No  Thur  Dinner     2    20.797159
#
#     day_encoded  size_encoded smoker_encoded sex_encoded
# 0     21.410000     16.448013      19.188278   18.056897
# ...

# %%
mean_bill = df.groupby(['tip', 'sex', 'smoker', 'day', 'time', 'size'])['total_bill'].mean().to_dict()
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_14128\4178713394.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_bill = df.groupby(['tip', 'sex', 'smoker', 'day', 'time', 'size'])['total_bill'].mean().to_dict()

# %%
mean_bill
# Out:
# {(1.0, 'Male', 'Yes', 'Thur', 'Lunch', 1): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Lunch', 2): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Lunch', 3): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Lunch', 4): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Lunch', 5): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Lunch', 6): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Dinner', 1): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Dinner', 2): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Dinner', 3): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Dinner', 4): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Dinner', 5): nan,
#  (1.0, 'Male', 'Yes', 'Thur', 'Dinner', 6): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Lunch', 1): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Lunch', 2): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Lunch', 3): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Lunch', 4): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Lunch', 5): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Lunch', 6): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Dinner', 1): nan,
#  (1.0, 'Male', 'Yes', 'Fri', 'Dinner', 2): nan,
# ...

# %%
df['encoded'] = df.groupby(['tip', 'sex', 'smoker', 'day', 'time', 'size'])['total_bill'].transform('mean')
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_14128\68327030.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['encoded'] = df.groupby(['tip', 'sex', 'smoker', 'day', 'time', 'size'])['total_bill'].transform('mean')

# %%
df[['tip', 'sex', 'smoker', 'day', 'time', 'size', 'encoded']]
# Out:
#       tip     sex smoker   day    time  size  encoded
# 0    1.01  Female     No   Sun  Dinner     2   16.990
# 1    1.66    Male     No   Sun  Dinner     3   10.340
# 2    3.50    Male     No   Sun  Dinner     3   21.010
# 3    3.31    Male     No   Sun  Dinner     2   23.680
# 4    3.61  Female     No   Sun  Dinner     4   24.590
# ..    ...     ...    ...   ...     ...   ...      ...
# 239  5.92    Male     No   Sat  Dinner     3   29.030
# 240  2.00  Female    Yes   Sat  Dinner     2   18.905
# 241  2.00    Male    Yes   Sat  Dinner     2   18.240
# 242  1.75    Male     No   Sat  Dinner     2   17.820
# 243  3.00  Female     No  Thur  Dinner     2   18.780
#
# [244 rows x 7 columns]
