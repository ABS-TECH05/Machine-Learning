# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')
df.head()
# Out:
#    day  month  year  Temperature  RH  ...  ISI  BUI  FWI      Classes  Region
# 0    1      6  2012           29  57  ...  1.3  3.4  0.5  not fire          0
# 1    2      6  2012           29  61  ...  1.0  3.9  0.4  not fire          0
# 2    3      6  2012           26  82  ...  0.3  2.7  0.1  not fire          0
# 3    4      6  2012           25  89  ...  0.0  1.7  0.0  not fire          0
# 4    5      6  2012           27  77  ...  1.2  3.9  0.5  not fire          0
#
# [5 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
##drop month,day and year
df.drop(['day', 'month', 'year'], axis=1, inplace=True)
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  ...  ISI  BUI  FWI      Classes  Region
# 0           29  57  18   0.0  65.7  ...  1.3  3.4  0.5  not fire          0
# 1           29  61  13   1.3  64.4  ...  1.0  3.9  0.4  not fire          0
# 2           26  82  22  13.1  47.1  ...  0.3  2.7  0.1  not fire          0
# 3           25  89  13   2.5  28.6  ...  0.0  1.7  0.0  not fire          0
# 4           27  77  16   0.0  64.8  ...  1.2  3.9  0.5  not fire          0
#
# [5 rows x 12 columns]

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## Encoding
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC  ...  ISI   BUI  FWI  Classes  Region
# 238           30  65  14   0.0  85.4  ...  4.5  16.9  6.5        1       1
# 239           28  87  15   4.4  41.1  ...  0.1   6.2  0.0        0       1
# 240           27  87  29   0.5  45.9  ...  0.4   3.4  0.2        0       1
# 241           24  54  18   0.1  79.7  ...  1.7   5.1  0.7        0       1
# 242           24  64  15   0.2  67.3  ...  1.2   4.8  0.5        0       1
#
# [5 rows x 12 columns]

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
## Independent And dependent features
X = df.drop('FWI', axis=1)
y = df['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
## Feature Selection based on correlaltion
X_train.corr()
# Out:
#              Temperature        RH        Ws  ...       BUI   Classes    Region
# Temperature     1.000000 -0.656095 -0.305977  ...  0.473609  0.542141  0.215212
# RH             -0.656095  1.000000  0.225736  ... -0.362317 -0.456876 -0.370114
# Ws             -0.305977  0.225736  1.000000  ...  0.035633 -0.082570 -0.204784
# Rain           -0.317512  0.241656  0.251932  ... -0.300964 -0.369357 -0.051010
# FFMC            0.694768 -0.653023 -0.190076  ...  0.607210  0.781259  0.201261
# DMC             0.498173 -0.414601  0.000379  ...  0.983175  0.617273  0.191090
# DC              0.390684 -0.236078  0.096576  ...  0.942414  0.543581 -0.079979
# ISI             0.629848 -0.717804 -0.023558  ...  0.643818  0.742977  0.273189
# BUI             0.473609 -0.362317  0.035633  ...  1.000000  0.612239  0.093528
# Classes         0.542141 -0.456876 -0.082570  ...  0.612239  1.000000  0.164565
# Region          0.215212 -0.370114 -0.204784  ...  0.093528  0.164565  1.000000
#
# [11 rows x 11 columns]

# %%
## Check for multicollinearity
plt.figure(figsize=(10,6))
corr = X_train.corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold--Domain expertise
corr_features = correlation(X_train, 0.85)

# %%
## drop features when correlation is more than 0.85 
X_train.drop(corr_features, axis=1, inplace=True)
X_test.drop(corr_features, axis=1, inplace=True)
X_train.shape, X_test.shape
# Out:
# ((182, 9), (61, 9))

# %% [markdown]
# ### Feature Scaling Or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -1.01105006],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  0.98907071],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  0.98907071],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -1.01105006],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  0.98907071],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -1.01105006]], shape=(182, 9))

# %% [markdown]
# ### Box Plots To understand Effect Of Standard Scaler

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train before scaled.')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train after scaled.')
plt.show()

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lr = LinearRegression()
lr.fit(X_train_scaled,y_train)
y_pred=lr.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error :", mae)
print("R2 Score :", score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error : 0.5418472431456679
# R2 Score : 0.9847409896321349

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
la = Lasso()
la.fit(X_train_scaled, y_train)
y_pred = la.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean absolute error :", mae)
print("R2 Score :", score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error : 1.1331759949144087
# R2 Score : 0.9492020263112388

# %% [markdown]
# #### Cross Validation Lasso

# %%
from sklearn.linear_model import LassoCV
lacv = LassoCV(cv=5)
lacv.fit(X_train_scaled, y_train)
# Out:
# LassoCV(cv=5)

# %%
lacv.alpha_
# Out:
# np.float64(0.05725391318234408)

# %%
lacv.alphas_
# Out:
# array([7.05853002, 6.58280872, 6.13914944, 5.72539132, 5.33951911,
#        4.97965339, 4.64404142, 4.33104857, 4.03915039, 3.76692517,
#        3.51304702, 3.27627941, 3.05546914, 2.84954075, 2.65749124,
#        2.47838523, 2.31135036, 2.15557308, 2.01029467, 1.87480753,
#        1.74845178, 1.63061198, 1.52071419, 1.41822315, 1.32263965,
#        1.23349817, 1.15036452, 1.0728338 , 1.00052839, 0.93309613,
#        0.87020857, 0.81155943, 0.75686304, 0.705853  , 0.65828087,
#        0.61391494, 0.57253913, 0.53395191, 0.49796534, 0.46440414,
#        0.43310486, 0.40391504, 0.37669252, 0.3513047 , 0.32762794,
#        0.30554691, 0.28495408, 0.26574912, 0.24783852, 0.23113504,
#        0.21555731, 0.20102947, 0.18748075, 0.17484518, 0.1630612 ,
#        0.15207142, 0.14182231, 0.13226397, 0.12334982, 0.11503645,
#        0.10728338, 0.10005284, 0.09330961, 0.08702086, 0.08115594,
#        0.0756863 , 0.0705853 , 0.06582809, 0.06139149, 0.05725391,
#        0.05339519, 0.04979653, 0.04644041, 0.04331049, 0.0403915 ,
#        0.03766925, 0.03513047, 0.03276279, 0.03055469, 0.02849541,
#        0.02657491, 0.02478385, 0.0231135 , 0.02155573, 0.02010295,
#        0.01874808, 0.01748452, 0.01630612, 0.01520714, 0.01418223,
#        0.0132264 , 0.01233498, 0.01150365, 0.01072834, 0.01000528,
#        0.00933096, 0.00870209, 0.00811559, 0.00756863, 0.00705853])

# %%
lacv.mse_path_
# Out:
# array([[54.04680834, 65.39074075, 54.89628985, 77.90299066, 39.38236846],
#        [46.99139504, 59.81506814, 49.29840831, 75.6645852 , 35.31758355],
#        [41.14908917, 53.9178721 , 42.49594889, 68.35708298, 31.76996123],
#        [36.05788169, 48.41773965, 36.66879347, 61.92819453, 28.67296816],
#        [31.62067285, 42.76466229, 31.68391904, 56.26841266, 24.93183295],
#        [27.75285367, 37.81922812, 27.42599138, 51.28216115, 21.56888645],
#        [24.3807738 , 33.49107651, 23.7950306 , 45.25481907, 18.66094162],
#        [ 0.73087149,  1.51213233,  7.86972079,  1.96274831,  0.81955927],
#        [ 0.72874717,  1.50935631,  7.90245613,  1.9582274 ,  0.82067768],
#        [ 0.72700933,  1.50676001,  7.90245613,  1.95403404,  0.82156407],
#        [ 0.72555319,  1.50491444,  7.93133459,  1.95022054,  0.82275473],
#        [ 0.72431871,  1.50304453,  7.94198661,  1.94666873,  0.82390687],
#        [ 0.72320449,  1.50151503,  7.94198661,  1.94349401,  0.82719784],
#        [ 0.7223122 ,  1.50000732,  7.96684436,  1.94062827,  0.82977824],
#        [ 0.72157491,  1.49879415,  7.96684436,  1.93840025,  0.83255006],
#        [ 0.72095742,  1.4977403 ,  7.98768542,  1.93699529,  0.83504341],
#        [ 0.72038903,  1.49672477,  7.99521   ,  1.93565502,  0.83757524],
#        [ 0.71994462,  1.49568226,  8.00375326,  1.93449777,  0.83983885],
#        [ 0.719596  ,  1.49472583,  8.01096918,  1.93347921,  0.84210843],
#        [ 0.71931191,  1.49375511,  8.01826869,  1.93259024,  0.84432122],
#        [ 0.7190445 ,  1.49295864,  8.01826869,  1.93175539,  0.84642004],
#        [ 0.71883572,  1.49227417,  8.03317062,  1.93103601,  0.84825582],
#        [ 0.71869159,  1.49166987,  8.03744108,  1.9304277 ,  0.85020764],
#        [ 0.7185831 ,  1.49106081,  8.04299181,  1.92983429,  0.85190082],
#        [ 0.71847961,  1.49054382,  8.04779515,  1.92931891,  0.85350887],
#        [ 0.71839015,  1.49011883,  8.05297791,  1.92887188,  0.85507602]])

# %%
y_pred = lacv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean absolute error:", mae)
print("R2 Score :", score)
plt.show()
# Out:
# Mean absolute error: 0.6140096605668078
# R2 Score : 0.9821497758969678

# %% [markdown]
# ### Ridge Regression model

# %%
from sklearn.linear_model import Ridge
ri = Ridge()
ri.fit(X_train_scaled, y_train)
y_pred = ri.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean absolute error :", mae)
print("R2 Score :", score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error : 0.5570319391738761
# R2 Score : 0.9842885204985738

# %% [markdown]
# #### Cross Validation Ridge

# %%
from sklearn.linear_model import RidgeCV
ricv = RidgeCV(cv=5)
ricv.fit(X_train_scaled, y_train)
y_pred = ricv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mae}')
print(f'R2 Score: {score}')
# Out:
# Mean Squared Error: 0.5570319391738761
# R2 Score: 0.9842885204985738

# %%
ricv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': False}

# %% [markdown]
# ### Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
el = ElasticNet()
el.fit(X_train_scaled, y_train)
y_pred = el.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean absolute error :", mae)
print("R2 Score :", score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error : 1.8822353634895999
# R2 Score : 0.8753460589519703

# %% [markdown]
# #### Cross Validation ElasticNet

# %%
from sklearn.linear_model import ElasticNetCV
elcv = ElasticNetCV(cv=5)
elcv.fit(X_train_scaled, y_train)
y_pred = elcv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mae}')
print(f'R2 Score: {score}')
# Out:
# Mean Squared Error: 0.6526811082911518
# R2 Score: 0.9814501507295914

# %%
elcv.get_params()
# Out:
# {'alphas': 'warn',
#  'copy_X': True,
#  'cv': 5,
#  'eps': 0.001,
#  'fit_intercept': True,
#  'l1_ratio': 0.5,
#  'max_iter': 1000,
#  'n_alphas': 'deprecated',
#  'n_jobs': None,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'verbose': 0}
